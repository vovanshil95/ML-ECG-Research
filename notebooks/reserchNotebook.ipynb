# %%
# !pip install plotly

# %%
import pandas as pd
import wfdb
import
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [30], line 3
#       1 import pandas as pd
#       2 import wfdb
# ----> 3 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %%
df = pd.read_csv('all_ecg.csv')

# %%
first_lead = df.iloc[::12]

# %%
df.iloc[::12].Age.hist()
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#     ID   Age  Gender      0      1      2      3      4      5      6  ...  \
# 0  0.0  85.0     1.0 -0.254 -0.342 -0.205 -0.220 -0.249 -0.312 -0.239  ...
# 1  0.0  85.0     1.0  0.264 -0.054  0.000  0.044  0.049 -0.112  0.088  ...
# 2  0.0  85.0     1.0  0.517  0.288  0.205  0.264  0.298  0.200  0.327  ...
# 3  0.0  85.0     1.0 -0.005  0.200  0.102  0.088  0.102  0.215  0.078  ...
# 4  0.0  85.0     1.0 -0.386 -0.317 -0.205 -0.244 -0.273 -0.259 -0.283  ...
#
#       91     92     93     94     95     96     97     98     99  \
# 0 -0.083 -0.220 -0.166 -0.054 -0.142 -0.142 -0.181 -0.107  0.029
# 1  0.024 -0.244 -0.024  0.020 -0.029 -0.073  0.190 -0.122 -0.049
# 2  0.107 -0.024  0.142  0.073  0.112  0.068  0.371 -0.015 -0.078
# 3  0.029  0.234  0.098  0.020  0.088  0.107 -0.005  0.117  0.010
# 4 -0.098 -0.098 -0.156 -0.063 -0.127 -0.107 -0.278 -0.049  0.054
#
#                       Diagnoses
# 0  164889003,59118001,164934002
# 1  164889003,59118001,164934002
# ...

# %%
children_data = df[df.Age <= 10]

# %%
children_data.iloc[::12]
# Out:
#              ID   Age  Gender      0      1      2      3      4      5  \
# 3396      283.0   4.0     1.0  0.054 -0.049 -0.010 -0.386  0.044  0.039
# 6624      552.0   7.0     0.0  0.239 -0.039 -0.029 -0.044 -0.059  0.151
# 9504      792.0   5.0     0.0 -0.054 -0.039  0.205 -0.068 -0.063 -0.117
# 10932     911.0   7.0     1.0  0.200  0.161  0.049  0.249  0.327  0.200
# 11004     917.0   7.0     1.0 -0.020  0.049 -0.034 -0.068 -0.063  0.146
# ...         ...   ...     ...    ...    ...    ...    ...    ...    ...
# 526464  43872.0   5.0     0.0 -0.083 -0.093  0.039 -0.015 -0.005  0.664
# 526476  43873.0   5.0     0.0 -0.146 -0.068 -0.122  0.098  0.112  0.015
# 526488  43874.0   5.0     0.0  0.102 -0.049 -0.498 -0.010  0.054 -0.068
# 526500  43875.0   6.0     1.0 -0.088 -0.049  0.166 -0.093 -0.107 -0.107
# 526536  43878.0  10.0     0.0 -0.068  0.000 -0.024  0.029  0.190 -0.010
#
#             6  ...     91     92     93     94     95     96     97     98  \
# ...

# %%
test_data = first_lead.sample(100)

# %%
testX = test_data.iloc[:,3:-1]
testY = test_data.iloc[:,-1]
testY.apply(lambda x: x.split(',')[0]).unique()
# Out:
# array(['426177001', '164889003', '164934002', '55827005', '164890007',
#        '426783006', '164930006', '427393009', '427084000', '284470004',
#        '365413008', '6374002'], dtype=object)

# %%
diagnoses = first_lead.iloc[:,-1].apply(lambda x: x.split(',')[0])
diagnoses.unique()
# Out:
# array(['164889003', '426177001', '164890007', '426783006', '427084000',
#        '164865005', '251146004', '164931005', '164934002', '426761007',
#        '713422000', '251166008', '17366009', '233897008', '111975006',
#        '29320008', '365413008', '251223006', '47665007', '284470004',
#        '164930006', '698252002', '89792004', '445118002', '713426002',
#        '55930002', '164873001', '55827005', '425856008', '429622005',
#        '106068003', '233917008', '713427006', '61721007', '6374002',
#        '426627000', '54329005', '427393009', '81898007', '75532003',
#        '61277005', '164896001', '111288001', '270492004', '426995002',
#        '164917005', '63593006', '54016002', '164947007', '426183003',
#        '195042002', '251120003', '164937009', '65778007', '50799005',
#        '59118001', '59931005', '10370003', '251187003', '427172004',
#        '445211001', '733534002', '426648003', '164909002', '39732003',
# ...

# %%
diagnoses = first_lead.iloc[:,-1].apply(lambda x: x.split(',')[0])
smallDiagnoses = diagnoses[(diagnoses == '164889003') | (diagnoses == '426177001') | (diagnoses == '164890007') 
                           | (diagnoses == '426783006') | (diagnoses == '427084000')]
smallDiagnoses.size
# Out:
# 35577

# %%
diagnoses.size
# Out:
# 43880

# %%
smallDiagnoses.unique()
# Out:
# array(['164889003', '426177001', '164890007', '426783006', '427084000'],
#       dtype=object)

# %%
conditions = pd.read_csv('a-large-scale-12-lead-electrocardiogram-database-for-arrhythmia-study-1.0.0\ConditionNames_SNOMED-CT.csv')
conditions[(conditions.Snomed_CT == 164889003) |
           (conditions.Snomed_CT == 426177001) |
           (conditions.Snomed_CT == 164890007) |
           (conditions.Snomed_CT == 426783006) |
           (conditions.Snomed_CT == 427084000)]
# Out:
#    Acronym Name            Full Name  Snomed_CT
# 52           SB    Sinus Bradycardia  426177001
# 53           SR         Sinus Rhythm  426783006
# 54         AFIB  Atrial Fibrillation  164889003
# 55           ST    Sinus Tachycardia  427084000
# 56           AF       Atrial Flutter  164890007

# %%
signals, fields = wfdb.rdsamp('a-large-scale-12-lead-electrocardiogram-database-for-arrhythmia-study-1.0.0/WFDBRecords/01/011/JS00106')
wfdb.plot_items(signals, figsize=(20, 15))

# %%
path = '/home/vladimir/PycharmProjects/ML-ECG-Research/data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
file_name = 'ptbxl_database.csv'
df = pd.read_csv(path+file_name, index_col='ecg_id')

# %%
df
# Out:
#         patient_id    age  sex  height  weight  nurse  site      device  \
# ecg_id
# 1          15709.0   56.0    1     NaN    63.0    2.0   0.0   CS-12   E
# 2          13243.0   19.0    0     NaN    70.0    2.0   0.0   CS-12   E
# 3          20372.0   37.0    1     NaN    69.0    2.0   0.0   CS-12   E
# 4          17014.0   24.0    0     NaN    82.0    2.0   0.0   CS-12   E
# 5          17448.0   19.0    1     NaN    70.0    2.0   0.0   CS-12   E
# ...            ...    ...  ...     ...     ...    ...   ...         ...
# 21833      17180.0   67.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21834      20703.0  300.0    0     NaN     NaN    1.0   2.0  AT-60    3
# 21835      19311.0   59.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21836       8873.0   64.0    1     NaN     NaN    1.0   2.0  AT-60    3
# 21837      11744.0   68.0    0     NaN     NaN    1.0   2.0  AT-60    3
#
#              recording_date  \
# ecg_id
# 1       1984-11-09 09:17:34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21799 entries, 1 to 21837
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   patient_id                    21799 non-null  float64
#  1   age                           21799 non-null  float64
#  2   sex                           21799 non-null  int64
#  3   height                        6974 non-null   float64
#  4   weight                        9421 non-null   float64
#  5   nurse                         20326 non-null  float64
#  6   site                          21782 non-null  float64
#  7   device                        21799 non-null  object
#  8   recording_date                21799 non-null  object
#  9   report                        21799 non-null  object
#  10  scp_codes                     21799 non-null  object
#  11  heart_axis                    13331 non-null  object
# ...

# %%
df[df.scp_codes.str.contains('IMI')].filename_hr
# Out:
# ecg_id
# 8        records500/00000/00008_hr
# 39       records500/00000/00039_hr
# 103      records500/00000/00103_hr
# 146      records500/00000/00146_hr
# 153      records500/00000/00153_hr
#                    ...
# 21815    records500/21000/21815_hr
# 21820    records500/21000/21820_hr
# 21826    records500/21000/21826_hr
# 21827    records500/21000/21827_hr
# 21828    records500/21000/21828_hr
# Name: filename_hr, Length: 2676, dtype: object

# %%
infarct_signals = df[df.scp_codes.str.contains('IMI')].filename_hr
normal_signals = df[df.scp_codes.str.contains('NORM')].filename_hr.sample(infarct_signals.size)

# %%
normal_signals
# Out:
# ecg_id
# 18590    records500/18000/18590_hr
# 2713     records500/02000/02713_hr
# 14409    records500/14000/14409_hr
# 7337     records500/07000/07337_hr
# 3761     records500/03000/03761_hr
#                    ...
# 6890     records500/06000/06890_hr
# 6492     records500/06000/06492_hr
# 16054    records500/16000/16054_hr
# 10960    records500/10000/10960_hr
# 7115     records500/07000/07115_hr
# Name: filename_hr, Length: 2676, dtype: object

# %%
p

# %%
normal_sig = wfdb.rdsamp(path + normal_signals.iloc[0], channels = [1])[0]
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0x10 but this version of numpy is 0xf
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [14], line 2
#       1 normal_sig = wfdb.rdsamp(path + normal_signals.iloc[0], channels = [1])[0]
# ----> 2 wfdb.plot_items(normal_sig)
#
# File ~/.local/lib/python3.11/site-packages/wfdb/plot/plot.py:245, in plot_items(signal, ann_samp, ann_sym, fs, time_units, sig_name, sig_units, xlabel, ylabel, title, sig_style, ann_style, ecg_grids, figsize, sharex, sharey, return_fig, return_fig_axes, sampling_freq, ann_freq)
#     119 def plot_items(
#     120     signal=None,
#     121     ann_samp=None,
#    (...)
#     139     ann_freq=None,
#     140 ):
#     141     """
# ...
